# %%
# Adaptive Multi-Modal Recommendation Engine — Demo

# %% [markdown]
# This notebook generates synthetic data, builds multimodal embeddings, trains the projection model, and evaluates Precision@k/Recall@k/NDCG.

# %%
# %pip install -r ../requirements.txt -q

# %%
import os
from importlib import reload

from src import preprocessing, model, evaluate, config

# %%
cfg = config.get_default_config()
print(cfg)

# %% [markdown]
# ## 1) Generate synthetic data and compute embeddings

# %%
# !python -m src.preprocessing --generate_synthetic --output_dir ../data

# %% [markdown]
# ## 2) Train projection model

# %%
# !python -m src.model --train --data_dir ../data --artifacts_dir ../data/artifacts

# %% [markdown]
# ## 3) Evaluate and visualize recommendations

# %%
# !python -m src.evaluate --data_dir ../data --artifacts_dir ../data/artifacts --topk 10
